# %%
import pandas as pd
import os

data_dir = "../data/physionet.org/files/mimiciv/3.1/"
icd_file = "diagnoses_icd.csv.gz"

icd_codes = {
    "diagnosis": ["Scoliosis", 
                  "Kyphosis", 
                  "Lodorosis", 
                  "Dorsopathy",
                 "Vertebral Fracture",
                 "Spondylosis",
                 "Spondyloisthesis"
                 ],
    "icd_10_code": ["M41", 
                    "M40.0", 
                    "M40.5",
                    "M40-3, M50-4",
                    "S12, S22.0, S32.0-2",
                    "M47",
                    "M43.1"
                   ],
    "icd_10_regex": ["^M41[0-9]*",
                    "^M40.0[0-9]*",
                    "^M40.5[0-9]*",
                    "(^M4[0-4][0-9]*)|(^M5[0-4][0-9]*)",
                    "^S12[0-9]*|^S220[0-9]*|^S32[0-2][0-9]*",
                    "^M47[0-9]*",
                    "^M431[0-9]*"
                    ],
    "icd_9_code": ["737.3",
                   "737.1",
                   "737.2",
                   "720-724",
                   "805-806, 839.0-5",
                   "721",
                   "756.12, 738.4"
                  ],
    "icd_9_regex": [
        "^7373[0-9]*",
        "^7311[0-9]*",
        "^7322[0-9]*",
        "^72[0-4][0-9]*",
        "(^80[5-6][0-9]*)|(^839[0-5][0-9]*)",
        "^721[0-9]*",
        "(^75612[0-9]*)|(^7384[0-9]*)"
    ],
}

icd_codes = pd.DataFrame.from_dict(icd_codes)
print(icd_codes)

data = pd.read_csv(os.path.join(data_dir, icd_file))
icd_9_data = data[data['icd_version'] == 9]
icd_10_data = data[data['icd_version'] == 10]
# Out:
#             diagnosis          icd_10_code  \
# 0           Scoliosis                  M41
# 1            Kyphosis                M40.0
# 2           Lodorosis                M40.5
# 3          Dorsopathy         M40-3, M50-4
# 4  Vertebral Fracture  S12, S22.0, S32.0-2
# 5         Spondylosis                  M47
# 6    Spondyloisthesis                M43.1
#
#                              icd_10_regex        icd_9_code  \
# 0                              ^M41[0-9]*             737.3
# 1                            ^M40.0[0-9]*             737.1
# 2                            ^M40.5[0-9]*             737.2
# 3       (^M4[0-4][0-9]*)|(^M5[0-4][0-9]*)           720-724
# 4  ^S12[0-9]*|^S220[0-9]*|^S32[0-2][0-9]*  805-806, 839.0-5
# 5                              ^M47[0-9]*               721
# 6                             ^M431[0-9]*     756.12, 738.4
#
#                           icd_9_regex
# 0                         ^7373[0-9]*
# 1                         ^7311[0-9]*
# 2                         ^7322[0-9]*
# 3                      ^72[0-4][0-9]*
# 4  (^80[5-6][0-9]*)|(^839[0-5][0-9]*)
# 5                          ^721[0-9]*
# 6        (^75612[0-9]*)|(^7384[0-9]*)

# %%
import pandas as pd
import os

data_dir = "../data/mimic-iv/physionet.org/files/mimiciv/3.1/"
data_file = "icu/d_items.csv.gz"

data = pd.read_csv(os.path.join(data_dir, data_file))
print(data[data['label'].str.contains("Ventilation")])
# Out:
#       itemid                          label                   abbreviation  \
# 1207  225303  Mask Ventilation (Intubation)  Mask Ventilation (Intubation)
# 1534  225792           Invasive Ventilation           Invasive Ventilation
# 1535  225794       Non-invasive Ventilation       Non-invasive Ventilation
#
#               linksto       category unitname param_type  lownormalvalue  \
# 1207      chartevents     Intubation      NaN       Text             NaN
# 1534  procedureevents  2-Ventilation      NaN  Processes             NaN
# 1535  procedureevents  2-Ventilation      NaN  Processes             NaN
#
#       highnormalvalue
# 1207              NaN
# 1534              NaN
# 1535              NaN

# %%
print(data['category'].unique())
# Out:
# ['General' 'ADT' 'Routine Vital Signs' 'Alarms' 'Hemodynamics' 'IABP'
#  'Cardiovascular (Pacer Data)' 'Respiratory' 'Labs'
#  'Ingredients - general (Not In Use)' 'Ingredients' 'Neurological'
#  'Fluids - Other (Not In Use)' 'Blood Products/Colloids' 'Fluids/Intake'
#  'Medications' 'Nutrition - Enteral' '5-Imaging' '4-Procedures'
#  'Nutrition - Supplements' 'Nutrition - Parenteral' 'Intubation'
#  'Pain/Sedation' 'Toxicology' 'ZIntake' 'Cardiovascular (Pulses)'
#  'Cardiovascular' 'Pulmonary' 'GI/GU' 'Restraint/Support Systems'
#  'Skin - Assessment' 'Skin - Incisions' 'Skin - Impairment' 'Treatments'
#  'Access Lines - Peripheral' 'Dialysis' 'Access Lines - Invasive'
#  'Impella' 'CVL Insertion' '1-Intubation/Extubation' 'Drains'
#  'PA Line Insertion' 'Lumbar Puncture' 'Thoracentesis'
#  'PICC Line Insertion' 'Adm History/FHPA' 'Paracentesis' '6-Cultures'
#  '3-Significant Events' 'Case Management' 'Bronchoscopy'
#  'Arterial Line Insertion' '2-Ventilation' 'Antibiotics' 'Output'
#  'Scores - APACHE II' 'Scores - APACHE IV (2)' 'Scores - APACHE IV'
#  'OB-GYN' 'OT Notes' 'ApacheII Parameters' 'ApacheIV Parameters'
#  '7-Communication' 'PiCCO' 'Tandem Heart' 'Family Mtg Note'
#  'Pastoral Care Note' 'NICOM' 'Generic Proc Note'
#  'Research Enrollment Note' 'MD Progress Note' 'Care Plans' 'Centrimag'
#  'ECMO' 'Heartware' 'Swallow Evaluation' 'SBNET' 'Triggers Note'
#  'RNTriggerNote' 'Durable VAD' 'RDOS' 'Block Charting Note'
#  'PatientSafetyInitialNote']

# %%
data_file = "icu/datetimeevents.csv.gz"

data = pd.read_csv(os.path.join(data_dir, data_file))
print(data)
# Out:
#          subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0          10000032  29079034  39553978         18704  2180-07-23 14:24:00
# 1          10000032  29079034  39553978         18704  2180-07-23 14:24:00
# 2          10000032  29079034  39553978         20925  2180-07-23 21:02:00
# 3          10000032  29079034  39553978         20925  2180-07-23 21:02:00
# 4          10000690  25860671  37081114         17393  2150-11-02 20:00:00
# ...             ...       ...       ...           ...                  ...
# 9979756    19999987  23865745  36195440         89300  2145-11-04 08:19:00
# 9979757    19999987  23865745  36195440         89300  2145-11-04 12:00:00
# 9979758    19999987  23865745  36195440         89300  2145-11-04 16:00:00
# 9979759    19999987  23865745  36195440         95520  2145-11-03 04:27:00
# 9979760    19999987  23865745  36195440         95520  2145-11-03 04:27:00
#
#                    storetime  itemid                value valueuom  warning
# 0        2180-07-23 14:24:00  225754  2180-07-23 14:24:00     Date        0
# 1        2180-07-23 14:24:00  225755  2180-07-23 14:24:00     Date        0
# 2        2180-07-23 21:02:00  225754  2180-07-23 00:00:00     Date        0
# 3        2180-07-23 21:02:00  225755  2180-07-23 00:00:00     Date        0
# 4        2150-11-03 04:53:00  225754  2150-11-02 04:53:00     Date        0
# ...                      ...     ...                  ...      ...      ...
# 9979756  2145-11-04 08:19:00  225754  2145-11-02 00:00:00     Date        0
# 9979757  2145-11-04 12:17:00  225755  2145-11-02 00:00:00     Date        0
# 9979758  2145-11-04 16:55:00  225755  2145-11-02 00:00:00     Date        0
# 9979759  2145-11-03 04:27:00  225754  2145-11-02 00:00:00     Date        0
# 9979760  2145-11-03 04:27:00  225755  2145-11-02 00:00:00     Date        0
#
# [9979761 rows x 10 columns]

# %%
print(icd_10_data)
# Out:
#          subject_id   hadm_id  seq_num icd_code  icd_version
# 40         10000084  23052089        1    G3183           10
# 41         10000084  23052089        2    F0280           10
# 42         10000084  23052089        3     R441           10
# 43         10000084  23052089        4     R296           10
# 44         10000084  23052089        5     E785           10
# ...             ...       ...      ...      ...          ...
# 6364453    19999828  29734428       18    Z9049           10
# 6364454    19999828  29734428       19   Z87891           10
# 6364455    19999828  29734428       20    B9620           10
# 6364456    19999828  29734428       21    Z1611           10
# 6364457    19999828  29734428       22    I9581           10
#
# [3455747 rows x 5 columns]

# %%
print(icd_9_data['icd_code'].value_counts())
# Out:
# icd_code
# 4019     102368
# 2724      67293
# 53081     48628
# 25000     43077
# 42731     37070
#           ...
# 71219         1
# 9251          1
# 9289          1
# V676          1
# 74519         1
# Name: count, Length: 9143, dtype: int64

# %%
print(icd_9_data[icd_9_data['icd_code'].str.contains("7373")])
# Out:
#          subject_id   hadm_id  seq_num icd_code  icd_version
# 114        10000690  23280645       15    73730            9
# 7561       10011365  26948481        8    73730            9
# 14834      10022880  27708593        2    73730            9
# 29993      10046440  22950616        4    73730            9
# 36220      10057009  20254095        9    73730            9
# ...             ...       ...      ...      ...          ...
# 6316465    19924481  23990922        6    73730            9
# 6331810    19949814  28015124        7    73730            9
# 6335803    19956723  27397573       19    73730            9
# 6341654    19965443  27874810       14    73739            9
# 6346017    19971734  29379955        9    73730            9
#
# [1115 rows x 5 columns]

# %%
print(icd_10_data['icd_code'].value_counts())
# Out:
# icd_code
# E785       84570
# I10        83775
# Z87891     62806
# K219       56157
# F329       41876
#            ...
# D106           1
# S42322B        1
# H33301         1
# H04301         1
# H04561         1
# Name: count, Length: 19440, dtype: int64

# %%
print(icd_10_data[icd_10_data['icd_code'].str.contains("^M41[0-9]*", regex=True)])
# Out:
#          subject_id   hadm_id  seq_num icd_code  icd_version
# 10006      10014451  21157275        2     M419           10
# 10532      10014967  25888738        3    M4156           10
# 27720      10041429  28466281        2     M419           10
# 36228      10057009  28491028        4    M4150           10
# 36728      10058522  26150386       21     M419           10
# ...             ...       ...      ...      ...          ...
# 6320294    19930893  24642043       10    M4180           10
# 6323020    19933841  29103434        2    M4186           10
# 6347819    19973795  23822974        3     M419           10
# 6357788    19990427  29695607       14     M419           10
# 6364451    19999828  29734428       16     M419           10
#
# [1015 rows x 5 columns]

# %%
for diagnosis in icd_codes.itertuples():
    icd_9_regex = diagnosis.icd_9_code
    icd_10_regex = diagnosis.icd_10_code
    filtered_icd9 = icd_9_data[icd_9_data['icd_code'].str.contains(icd_9_regex)]
    filtered_icd10 = icd_10_data[icd_10_data['icd_code'].str.contains(icd_10_regex)]
    print(diagnosis.diagnosis, len(filtered_icd9.subject_id.unique()), len(filtered_icd10.subject_id.unique()))
# Out:
# Scoliosis 29 806
# Kyphosis 42 202
# Lodorosis 15 7
# Dorsopathy 0 0
# Vertebral Fracture 0 0
# Spondylosis 4835 2816
# Spondyloisthesis 0 1

# %%
data = icd_9_data[icd_9_data['icd_code'].str.contains("^7373[0-9]*")]
unique_ids = data["subject_id"].unique()
print(len(unique_ids))
print(data["icd_code"].value_counts())
# Out:
# 805
# icd_code
# 73730    1018
# 73739      67
# 73734      19
# 73732       3
# 73733       1
# Name: count, dtype: int64

# %%
data = icd_10_data[icd_10_data['icd_code'].str.contains("^M41[0-9]*")]
unique_ids = data["subject_id"].unique()
print(len(unique_ids))
print(data["icd_code"].value_counts())
# Out:
# 806
# icd_code
# M419      808
# M4186      88
# M4180      24
# M4185      17
# M4156      15
# M4126      11
# M4187       9
# M4140       7
# M4120       7
# M4150       4
# M4135       4
# M41129      4
# M4134       4
# M4184       3
# M4124       2
# M4182       2
# M4152       1
# M4154       1
# M41126      1
# M41124      1
# M4183       1
# M41127      1
# Name: count, dtype: int64

# %%
import re
import pandas as pd
import os

data_dir = "../data/mimic-iv/physionet.org/files/mimic-iv-note/2.2/note/"
data_file = "discharge.csv.gz"

data = pd.read_csv(os.path.join(data_dir, data_file))

positive_keywords = [
    r"\bposture\b",
    r"stooped",
    r"kyphotic",
    r"slouched",
    r"hunched",
    r"poor posture",
    r"flexed posture",
    r"slumped posture",
    r"extended posture",
    r"bent posture",
    r"erect posture",
    r"forward head posture",
    r"asymmetrical posture",
    r"decortiate posture",
]

exclude_keywords = [
    r"normal posture",
    r"normal gait and posture",
    r"normal stance and posture",
    r"posture normal",
    r"good posture",
    r"appropriate posture",
    r"no postural abnormality",
    r"no abnormal posture"
]

pos_pattern = re.compile("|".join(positive_keywords), re.IGNORECASE)
exc_pattern = re.compile("|".join(exclude_keywords), re.IGNORECASE)

abnormal = data['text'].str.contains(pos_pattern, regex=True)
normal = data['text'].str.contains(exc_pattern, regex=True)
posture_notes = data[abnormal & ~normal]
print(posture_notes)
print(len(posture_notes))
# Out:
#                note_id  subject_id   hadm_id note_type  note_seq  \
# 220     10005606-DS-17    10005606  29646384        DS        17
# 270      10006825-DS-8    10006825  29669544        DS         8
# 285     10007920-DS-20    10007920  26693451        DS        20
# 399     10011938-DS-19    10011938  24772774        DS        19
# 439     10013502-DS-20    10013502  20363238        DS        20
# ...                ...         ...       ...       ...       ...
# 331193   19981958-DS-8    19981958  21856502        DS         8
# 331279  19985349-DS-10    19985349  20308632        DS        10
# 331320   19985885-DS-9    19985885  25048461        DS         9
# 331378  19987238-DS-26    19987238  28310249        DS        26
# 331602  19994259-DS-21    19994259  21818613        DS        21
#
#                   charttime            storetime  \
# 220     2143-12-16 00:00:00  2143-12-16 09:33:00
# 270     2150-08-10 00:00:00  2150-08-10 22:56:00
# 285     2136-08-30 00:00:00  2136-09-05 12:44:00
# 399     2132-01-30 00:00:00  2132-01-31 16:46:00
# 439     2159-01-13 00:00:00  2159-01-13 09:49:00
# ...                     ...                  ...
# 331193  2158-11-14 00:00:00  2158-11-14 16:40:00
# 331279  2125-07-19 00:00:00  2125-07-26 17:26:00
# 331320  2176-08-23 00:00:00  2176-08-26 10:10:00
# 331378  2165-09-11 00:00:00  2165-09-11 20:22:00
# 331602  2128-11-27 00:00:00  2128-11-29 13:54:00
#
#                                                      text
# 220      \nName:  ___              ___ No:   ___\n \nA...
# 270      \nName:  ___                    Unit No:   __...
# 285      \nName:  ___.              Unit No:   ___\n \...
# 399      \nName:  ___                Unit No:   ___\n ...
# 439      \nName:  ___            Unit No:   ___\n \nAd...
# ...                                                   ...
# 331193   \nName:  ___                   Unit No:   ___...
# 331279   \nName:  ___                    Unit No:   __...
# 331320   \nName:  ___                     Unit No:   _...
# 331378   \nName:  ___                    Unit No:   __...
# 331602   \nName:  ___                  Unit No:   ___\...
#
# [3001 rows x 8 columns]
# 3001

# %%
print(len(posture_notes['subject_id'].unique()))
posture_notes.to_csv("../output/abnormal_posture_notes.csv")
# Out:
# 2695

# %%
normal_posture_notes = data[normal & ~abnormal]
print(len(normal_posture_notes))
normal_posture_notes.to_csv("../output/normal_posture_notes.csv")
# Out:
# 2
